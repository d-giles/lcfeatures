# %%
import pandas as pd
import sys
sys.path.append('python')
import quarterTools as qt
from clusterOutliers import clusterOutliers as coo

# %%
tabby = qt.weirdnessProfile()
# Out:
# Scores of KIC 8462852
#      dist_score  PCA90_score  PCA95_score  PCA99_score
# Q4     0.004267     0.004000     0.004735     0.005831
# Q8     0.012796     0.015254     0.025468     0.030382
# Q11    0.000733     0.001318     0.001665     0.002019
# Q16    0.010713     0.009770     0.014559     0.019311
#         Full  Full_pctl    PCA90  PCA90_pctl    PCA95  PCA95_pctl    PCA99  \
# Q4   10073.0  93.275875   9574.0   93.609010  11756.0   92.152294  18093.0
# Q8    1783.0  98.810327   1877.0   98.747572   1292.0   99.138121   1628.0
# Q11  57109.0  61.874370  46651.0   68.856191  51626.0   65.534852  56875.0
# Q16   2619.0  98.252208   3078.0   97.945777   2598.0   98.266228   2848.0
#
#      PCA99_pctl
# Q4    87.921676
# Q8    98.913805
# Q11   62.030590
# Q16   98.099326
# KIC8462852 contained in these catalogs: dict_keys(['Deb_Class_ACT', 'SIMBAD_Class_*'])
# Significant deviation (>1 sigma) from Deb_Class_ACT catalog in Quarter Q8
# ...

# %%
for ctlg in tabby.catalogs:
    plt.figure()
    tabby.ctlgCmpViz(ctlg,'PCA99')

# %%
tabby = qt.weirdnessProfile()
# Out:
# Scores of KIC 8462852
#      dist_score  PCA90_score  PCA95_score  PCA99_score
# Q4     0.004267     0.004000     0.004735     0.005831
# Q8     0.012796     0.015254     0.025468     0.030382
# Q11    0.000733     0.001318     0.001665     0.002019
# Q16    0.010713     0.009770     0.014559     0.019311
#         Full  Full_pctl    PCA90  PCA90_pctl    PCA95  PCA95_pctl    PCA99  \
# Q4   10073.0  93.275875   9574.0   93.609010  11756.0   92.152294  18093.0
# Q8    1783.0  98.810327   1877.0   98.747572   1292.0   99.138121   1628.0
# Q11  57109.0  61.874370  46651.0   68.856191  51626.0   65.534852  56875.0
# Q16   2619.0  98.252208   3078.0   97.945777   2598.0   98.266228   2848.0
#
#      PCA99_pctl
# Q4    87.921676
# Q8    98.913805
# Q11   62.030590
# Q16   98.099326
# KIC8462852 contained in these catalogs: dict_keys(['Deb_Class_ACT', 'SIMBAD_Class_*'])
# Significant deviation (>1 sigma) from Deb_Class_ACT catalog in Quarter Q8
# ...

# %%
tabby.ctlgCmpViz('SIMBAD_Class_*')
plt.show()

# %%
Q1_1 = qt.weirdnessProfile('kplr005944707')
# Out:
# Scores of KIC 5944707
#      dist_score  PCA90_score  PCA95_score  PCA99_score
# Q4     0.000567     0.000391     0.000695     0.001034
# Q8     0.000294     0.000214     0.000360     0.001138
# Q11    0.000361     0.000694     0.000803     0.000603
# Q16    0.000357     0.000172     0.000472     0.000650
#          Full  Full_pctl     PCA90  PCA90_pctl     PCA95  PCA95_pctl  \
# Q4   108061.0  27.858521  120677.0   19.436007  110361.0   26.323028
# Q8   140029.0   6.516500  146122.0    2.448778  144117.0    3.787328
# Q11  109874.0  26.648152   87338.0   41.693315  103751.0   30.735902
# Q16  134447.0  10.243075  145316.0    2.986868  131960.0   11.903411
#
#         PCA99  PCA99_pctl
# Q4   110091.0   26.503281
# Q8   109895.0   26.634132
# Q11  138152.0    7.769596
# Q16  138854.0    7.300937
# KIC5944707 contained in these catalogs: dict_keys(['no_signal', 'Deb_Class_MISC', 'SIMBAD_Class_V*'])

# %%
Q1_2 = qt.weirdnessProfile('8415928')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-36ace532593c> in <module>
# ----> 1 Q1_2 = qt.weirdnessProfile('8415928')
#
# ~/workspace/KeplerML/python/quarterTools.py in __init__(self, KIC, Qs, analysis_path, fitsDirPath, verbose)
#     650         self.full_analysis_data = {Q:pd.read_csv(self.analysis_path+Q+'_analysis.csv',index_col=0) for Q in self.Qs}
#     651         self.analysis_data = {Q:self.sampler(self.full_analysis_data[Q]) for Q in self.Qs}
# --> 652         self.scores = self.scoreSummary()
#     653         self.ranks = self.rankSummary()
#     654         self.catalogs,self.ctlg_sampler = self.catalogCheck()
#
# ~/workspace/KeplerML/python/quarterTools.py in scoreSummary(self)
#     660         for Q in self.Qs:
#     661             dftmp = self.analysis_data[Q].loc[:,['dist_score','PCA90_score','PCA95_score','PCA99_score']]
# ...

# %%
Q1_2.plotlcs()

# %%
import sys
import numpy as np
np.set_printoptions(threshold=sys.maxsize)
import pandas as pd
import featurecalc as fc

# %% [markdown]
# Features can be generated from the terminal using the following command:
# ```
# python keplerml.py data/filelists/ex_filelist.txt data/lightcurves/ data/output/Example_output.p
# ```
# This requires a Python 3+ to be the default version, replace `python` with an appropriate version if this is not the case, for example, use `python3.7`
#
# The above terminal command is equivalent to the following:

# %%
path_to_filelist = './data/filelists/ex_filelist.txt'
path_to_fits = './data/lightcurves/'
output_file = 'data/output/Example_output.p'
features = fc.features_from_filelist(path_to_filelist,path_to_fits,output_file,fl_as_array=False,verbose=True,prime_feats=False)
# Out:
# Reading ./data/filelists/ex_filelist.txt...
# Using 7 cpus to calculate features...
# Importing 247 lightcurves...
# Lightcurve import took 0:00:02.421393
# Processing 247 files...
# Features have been calculated, total time to calculate features: 0:00:15.492518
# Saving output to data/output/Example_output.p
# Cleaning up...
# Done.

# %% [markdown]
# Features are returned in a Pandas DataFrame, and saved to the specified output file as a pickled dataframe, which can be read in using the pickle module

# %%
feats
# Out:
#                                       longtermtrend  meanmedrat     skews  \
# kplr001026032-2011271113734_llc.fits  -6.415193e-07    0.998779 -7.109529
# kplr001026957-2011271113734_llc.fits   8.002484e-07    1.000916  0.396550
# kplr001433962-2011271113734_llc.fits   2.901455e-07    0.998548 -0.267555
# kplr001571511-2011271113734_llc.fits  -3.231966e-08    0.999619 -6.939159
# kplr001725193-2011271113734_llc.fits  -1.793919e-06    0.998417 -3.711617
# ...                                             ...         ...       ...
# kplr012059158-2011271113734_llc.fits   1.117457e-05    0.999223 -0.197160
# kplr012121738-2011271113734_llc.fits   2.720706e-07    0.999986 -0.289638
# kplr012153021-2011271113734_llc.fits  -1.237327e-07    1.000001 -0.005169
# kplr012166770-2011271113734_llc.fits  -1.220384e-07    1.000000  0.191987
# kplr012217324-2011271113734_llc.fits  -1.324410e-07    1.000001 -0.169118
#
#                                              varss  coeffvar      stds  \
# kplr001026032-2011271113734_llc.fits  6.701708e-05  0.008196  0.008186
# kplr001026957-2011271113734_llc.fits  3.241609e-05  0.005688  0.005694
# kplr001433962-2011271113734_llc.fits  3.002621e-05  0.005488  0.005480
# kplr001571511-2011271113734_llc.fits  6.610586e-06  0.002572  0.002571
# kplr001725193-2011271113734_llc.fits  5.186898e-05  0.007213  0.007202
# ...                                            ...       ...       ...
# kplr012059158-2011271113734_llc.fits  3.850392e-04  0.019638  0.019622
# kplr012121738-2011271113734_llc.fits  4.057132e-08  0.000201  0.000201
# kplr012153021-2011271113734_llc.fits  5.037641e-10  0.000022  0.000022
# kplr012166770-2011271113734_llc.fits  3.634115e-09  0.000060  0.000060
# kplr012217324-2011271113734_llc.fits  2.394776e-09  0.000049  0.000049
#
#                                      numoutliers numnegoutliers  \
# kplr001026032-2011271113734_llc.fits          56             56
# kplr001026957-2011271113734_llc.fits           0              0
# kplr001433962-2011271113734_llc.fits           0              0
# kplr001571511-2011271113734_llc.fits          81             81
# kplr001725193-2011271113734_llc.fits         117            117
# ...                                          ...            ...
# kplr012059158-2011271113734_llc.fits           0              0
# kplr012121738-2011271113734_llc.fits           2              1
# kplr012153021-2011271113734_llc.fits          10              5
# kplr012166770-2011271113734_llc.fits           3              0
# kplr012217324-2011271113734_llc.fits           1              0
#
#                                      numposoutliers numout1s  ...  percentamp  \
# kplr001026032-2011271113734_llc.fits              0      163  ...    0.086309
# kplr001026957-2011271113734_llc.fits              0     1474  ...    0.013276
# kplr001433962-2011271113734_llc.fits              0     1790  ...    0.013524
# kplr001571511-2011271113734_llc.fits              0       94  ...    0.021482
# kplr001725193-2011271113734_llc.fits              0      259  ...    0.042875
# ...                                             ...      ...  ...         ...
# kplr012059158-2011271113734_llc.fits              0     1829  ...    0.039670
# kplr012121738-2011271113734_llc.fits              1     1409  ...    0.001093
# kplr012153021-2011271113734_llc.fits              5     1310  ...    0.000200
# kplr012166770-2011271113734_llc.fits              3     1367  ...    0.000415
# kplr012217324-2011271113734_llc.fits              1     1581  ...    0.000244
#
#                                       magratio  sautocorrcoef  autocorrcoef  \
# kplr001026032-2011271113734_llc.fits  0.076923       0.742404      0.937333
# kplr001026957-2011271113734_llc.fits  0.616403      -0.294359      0.999479
# kplr001433962-2011271113734_llc.fits  0.502052      -0.486633      0.978182
# kplr001571511-2011271113734_llc.fits  0.069174       0.510130      0.968878
# kplr001725193-2011271113734_llc.fits  0.136161       0.789440      0.957196
# ...                                        ...            ...           ...
# kplr012059158-2011271113734_llc.fits  0.479063       0.854142      0.866823
# kplr012121738-2011271113734_llc.fits  1.035104      -0.386789      0.667244
# kplr012153021-2011271113734_llc.fits  1.603202      -0.502212      0.570701
# kplr012166770-2011271113734_llc.fits  1.466150      -0.489317      0.371749
# kplr012217324-2011271113734_llc.fits  1.218642      -0.467954      0.915432
#
#                                       flatmean  tflatmean  roundmean  \
# kplr001026032-2011271113734_llc.fits  0.034865   0.108202  -0.723083
# kplr001026957-2011271113734_llc.fits  0.002733   0.003749   0.047433
# kplr001433962-2011271113734_llc.fits  0.019154   0.018673  -0.003119
# kplr001571511-2011271113734_llc.fits  0.007759   0.006047  -0.089364
# kplr001725193-2011271113734_llc.fits  0.055880   0.210136  -1.015293
# ...                                        ...        ...        ...
# kplr012059158-2011271113734_llc.fits  0.985690   1.066900   1.846490
# kplr012121738-2011271113734_llc.fits  0.004670   0.004936  -0.034056
# kplr012153021-2011271113734_llc.fits  0.000285   0.000315   0.002465
# kplr012166770-2011271113734_llc.fits  0.001185   0.000996  -0.011266
# kplr012217324-2011271113734_llc.fits  0.000298   0.000290   0.001286
#
#                                       troundmean   roundrat   flatrat
# kplr001026032-2011271113734_llc.fits    0.031835 -22.713754  0.322218
# kplr001026957-2011271113734_llc.fits   -0.012429  -3.816354  0.728774
# kplr001433962-2011271113734_llc.fits    0.165303  -0.018868  1.025801
# kplr001571511-2011271113734_llc.fits    0.196277  -0.455296  1.283076
# kplr001725193-2011271113734_llc.fits    0.573217  -1.771219  0.265923
# ...                                          ...        ...       ...
# kplr012059158-2011271113734_llc.fits    1.957067   0.943499  0.923882
# kplr012121738-2011271113734_llc.fits    0.049081  -0.693884  0.946016
# kplr012153021-2011271113734_llc.fits   -0.001459  -1.689899  0.904275
# kplr012166770-2011271113734_llc.fits    0.005768  -1.953339  1.189901
# kplr012217324-2011271113734_llc.fits   -0.001709  -0.752664  1.027726
#
# [247 rows x 60 columns]

# %%
import pickle

# %%
output_file = 'data/output/Example_output.p'
with open(output_file,'rb') as f:
    feats = pickle.load(f)
feats
# Out:
#                                       longtermtrend  meanmedrat     skews  \
# kplr010000500-2011177032512_llc.fits   1.683499e-06    0.999973  0.016686
# kplr006283224-2011271113734_llc.fits  -1.101001e-06    0.978003 -1.969707
# kplr010556068-2011271113734_llc.fits  -7.715069e-06    0.999729 -0.118850
# kplr009874575-2011271113734_llc.fits   1.925566e-05    1.001603  0.247914
# kplr007800003-2011177032512_llc.fits  -4.768483e-06    1.000060  0.696015
# ...                                             ...         ...       ...
# kplr008143757-2011271113734_llc.fits   1.458561e-04    0.955739 -0.408871
# kplr012153021-2011271113734_llc.fits  -1.237327e-07    1.000001 -0.005169
# kplr009351622-2011271113734_llc.fits  -9.565055e-07    1.000013  0.020581
# kplr002305543-2011271113734_llc.fits   4.096887e-05    0.991888 -2.270881
# kplr009724080-2011271113734_llc.fits  -3.399187e-05    1.001219  0.060556
#
#                                              varss  coeffvar      stds  \
# kplr010000500-2011177032512_llc.fits  7.494065e-07  0.000866  0.000866
# kplr006283224-2011271113734_llc.fits  3.143497e-03  0.057328  0.056067
# kplr010556068-2011271113734_llc.fits  3.462362e-05  0.005886  0.005884
# kplr009874575-2011271113734_llc.fits  5.324820e-03  0.072855  0.072971
# kplr007800003-2011177032512_llc.fits  2.020982e-07  0.000450  0.000450
# ...                                            ...       ...       ...
# kplr008143757-2011271113734_llc.fits  2.489258e-02  0.165080  0.157774
# kplr012153021-2011271113734_llc.fits  5.037641e-10  0.000022  0.000022
# kplr009351622-2011271113734_llc.fits  2.601213e-06  0.001613  0.001613
# kplr002305543-2011271113734_llc.fits  8.325439e-04  0.029090  0.028854
# kplr009724080-2011271113734_llc.fits  4.712454e-04  0.021682  0.021708
#
#                                      numoutliers numnegoutliers  \
# kplr010000500-2011177032512_llc.fits           0              0
# kplr006283224-2011271113734_llc.fits           0              0
# kplr010556068-2011271113734_llc.fits           0              0
# kplr009874575-2011271113734_llc.fits           0              0
# kplr007800003-2011177032512_llc.fits           1              0
# ...                                          ...            ...
# kplr008143757-2011271113734_llc.fits           0              0
# kplr012153021-2011271113734_llc.fits          10              5
# kplr009351622-2011271113734_llc.fits           0              0
# kplr002305543-2011271113734_llc.fits           8              8
# kplr009724080-2011271113734_llc.fits           0              0
#
#                                      numposoutliers numout1s  ...  percentamp  \
# kplr010000500-2011177032512_llc.fits              0     1636  ...    0.002916
# kplr006283224-2011271113734_llc.fits              0      654  ...    0.222484
# kplr010556068-2011271113734_llc.fits              0     2082  ...    0.011008
# kplr009874575-2011271113734_llc.fits              0     1774  ...    0.169323
# kplr007800003-2011177032512_llc.fits              1     1430  ...    0.001956
# ...                                             ...      ...  ...         ...
# kplr008143757-2011271113734_llc.fits              0     1942  ...    0.319511
# kplr012153021-2011271113734_llc.fits              5     1310  ...    0.000200
# kplr009351622-2011271113734_llc.fits              0     1518  ...    0.004658
# kplr002305543-2011271113734_llc.fits              0      541  ...    0.127376
# kplr009724080-2011271113734_llc.fits              0     1982  ...    0.043748
#
#                                       magratio  sautocorrcoef  autocorrcoef  \
# kplr010000500-2011177032512_llc.fits  0.773874      -0.485011      0.838348
# kplr006283224-2011271113734_llc.fits  0.155552       0.459622      0.763723
# kplr010556068-2011271113734_llc.fits  0.530927       0.963298      0.991826
# kplr009874575-2011271113734_llc.fits  0.667820       0.712814      0.750983
# kplr007800003-2011177032512_llc.fits  0.946602      -0.504644      0.870647
# ...                                        ...            ...           ...
# kplr008143757-2011271113734_llc.fits  0.351238       0.655009      0.721065
# kplr012153021-2011271113734_llc.fits  1.603202      -0.502212      0.570701
# kplr009351622-2011271113734_llc.fits  0.622291       0.770837      0.811944
# kplr002305543-2011271113734_llc.fits  0.173412       0.573375      0.840457
# kplr009724080-2011271113734_llc.fits  0.590106       0.234101      0.942884
#
#                                       flatmean  tflatmean   roundmean  \
# kplr010000500-2011177032512_llc.fits  0.006864   0.005877    0.021789
# kplr006283224-2011271113734_llc.fits  0.376210   2.905230  -29.443737
# kplr010556068-2011271113734_llc.fits  0.031546   0.036233   -0.921686
# kplr009874575-2011271113734_llc.fits  3.329066   2.650239   78.161661
# kplr007800003-2011177032512_llc.fits  0.003376   0.003127   -0.014711
# ...                                        ...        ...         ...
# kplr008143757-2011271113734_llc.fits  6.054313   6.867673  219.527612
# kplr012153021-2011271113734_llc.fits  0.000285   0.000315    0.002465
# kplr009351622-2011271113734_llc.fits  0.087393   0.085143    1.152797
# kplr002305543-2011271113734_llc.fits  0.101980   1.748088   -3.670530
# kplr009724080-2011271113734_llc.fits  0.453956   0.378110   -8.878043
#
#                                       troundmean   roundrat   flatrat
# kplr010000500-2011177032512_llc.fits   -0.042319  -0.514868  1.167939
# kplr006283224-2011271113734_llc.fits    3.769187  -7.811695  0.129494
# kplr010556068-2011271113734_llc.fits    1.093799  -0.842647  0.870643
# kplr009874575-2011271113734_llc.fits  -88.598113  -0.882205  1.256138
# kplr007800003-2011177032512_llc.fits    0.004245  -3.465757  1.079394
# ...                                          ...        ...       ...
# kplr008143757-2011271113734_llc.fits -156.015214  -1.407091  0.881567
# kplr012153021-2011271113734_llc.fits   -0.001459  -1.689899  0.904275
# kplr009351622-2011271113734_llc.fits   -1.146191  -1.005764  1.026424
# kplr002305543-2011271113734_llc.fits    0.280097 -13.104517  0.058338
# kplr009724080-2011271113734_llc.fits    7.028935  -1.263071  1.200593
#
# [247 rows x 60 columns]

# %% [markdown]
# The features are optimized using the `@njit` decorator from the `numba` package. To make full use of this, the code to be optimized by numba needs to run once. This can be done manually as follows:

# %%
lc_path = './data/lightcurves/kplr001026032-2011271113734_llc.fits'
lc = fc.import_lcs(lc_path)
t = lc[1]
nf = lc[2]
err = lc[3]
lc_feats = fc.feats(t,nf,err)

# %% [markdown]
# After priming the feature calculation, the features for a filelist can be run in the same way as before.
# As a note, the `features_from_filelist` method will run a primer by default using the first lightcurve. Whether primed manually as above, with the default, or even run specifically without priming, runs following the first will be optimized by `numba` and be quicker.
#
# Note the drastically improved runtime following the manual priming above:

# %%
path_to_filelist = './data/filelists/ex_filelist.txt'
path_to_fits = './data/lightcurves/'
output_file = 'data/output/Example_output.p'
features = fc.features_from_filelist(path_to_filelist,path_to_fits,output_file,fl_as_array=False,verbose=True,prime_feats=False)
# Out:
# Reading ./data/filelists/ex_filelist.txt...
# Using 7 cpus to calculate features...
# Importing 247 lightcurves...
# Lightcurve import took 0:00:01.687273
# Processing 247 files...
# Features have been calculated, total time to calculate features: 0:00:01.078100
# Saving output to data/output/Example_output.p
# Cleaning up...
# Done.

# %% [markdown]
# The file list can also be fed into the feature calculator as a list of filenames, produced however. Two examples below.

# %%
path_to_filelist = './data/filelists/ex_filelist.txt'
with open(path_to_filelist,'r') as f:
    files = f.read().splitlines()
path_to_fits = './data/lightcurves/'
output_file = 'data/output/Example_output.p'
feats = fc.features_from_filelist(files,path_to_fits,output_file,fl_as_array=True,verbose=True)
# Out:
# Using 7 cpus to calculate features...
# Importing 247 lightcurves...
# Lightcurve import took 0:00:02.401971
# Processing 247 files...
# Features have been calculated, total time to calculate features: 0:00:01.099379
# Saving output to data/output/Example_output.p
# Cleaning up...
# Done.

# %%
import os

# %%
path_to_fits = './data/lightcurves/'
files = os.listdir('data/lightcurves')
output_file = 'data/output/Example_output.p'
feats = fc.features_from_filelist(files,path_to_fits,output_file,fl_as_array=True,verbose=True)
# Out:
# Using 7 cpus to calculate features...
# Importing 247 lightcurves...
# Lightcurve import took 0:00:02.701503
# Processing 247 files...
# Features have been calculated, total time to calculate features: 0:00:01.098045
# Saving output to data/output/Example_output.p
# Cleaning up...
# Done.
